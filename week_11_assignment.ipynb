# %%
#importing functions

import numpy as np
import pandas as pd
import requests
import json as json

#setting up display options
pd.set_option('display.notebook_repr_html',True)
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
def simpleSearch(strQuery, strStartDate, strEndDate):
    
    #setting the URL for the API
    strURL = 'https://api.nytimes.com/svc/search/v2/articlesearch.json'
    
    #creating a dictionary with supplied parameters
    dictParams = {'api-key': "Be3RKQ6rJKWTADKRGoNovnN6AM6O8igN",
                 'q': strQuery,
                 'start_date': strStartDate,
                 'end_date': strEndDate,
                 'page': 1}
    
    #returning the jsons request
    return(requests.get(strURL, params = dictParams))

# %%
#sending request to ny times
nytResponse = simpleSearch("Hello", 20200101, 20210101)

#converting to the python dictionary
jsonresults = nytResponse.json()['response']['docs']

# %%
#using the normalize function to cleanup the data
dfNYT_Results = pd.io.json.json_normalize(jsonresults)
# Out:
# C:\Users\13472\AppData\Local\Temp/ipykernel_4124/2232615628.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dfNYT_Results = pd.io.json.json_normalize(jsonresults)

# %%
#display the contents
dfNYT_Results
# Out:
#                                             abstract  \
# 0  The ethnic patterns, colors and embellishment ...
# 1  At least half a dozen advertising campaigns ar...
# 2  General Electric continues is green marketing ...
# 3  An English lesson in a school in a Hyderabad s...
# 4  Southern New England Telephone Co, celebrating...
# 5  For those Manhattanites who rarely set foot in...
# 6    "Pay me or trade me. Click." That, more or l...
# 7  Lawrence N Stevenson resigns from Pep Boys aft...
# 8    IF YOU WANT TO GET with it in terms of nomen...
# 9  Papatzul, Mexican restaurant in SoHo, offers h...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2005/05/29/style/on-th...
# 1  https://www.nytimes.com/2007/05/24/business/me...
# 2  https://mediadecoder.blogs.nytimes.com/2010/09...
# 3  https://india.blogs.nytimes.com/2012/01/03/hel...
# 4  https://www.nytimes.com/1998/11/15/nyregion/fr...
# 5  https://www.nytimes.com/2014/02/09/nyregion/he...
# 6  https://www.nytimes.com/1992/08/16/sports/spor...
# 7  https://www.nytimes.com/2006/07/23/business/op...
# 8  https://www.nytimes.com/1995/03/12/magazine/on...
# 9  https://www.nytimes.com/2006/12/31/fashion/hel...
#
#                                              snippet  \
# 0  The ethnic patterns, colors and embellishment ...
# 1  At least half a dozen advertising campaigns ar...
# 2  General Electric continues is green marketing ...
# 3  An English lesson in a school in a Hyderabad s...
# 4  Southern New England Telephone Co, celebrating...
# 5  For those Manhattanites who rarely set foot in...
# 6
# 7  Lawrence N Stevenson resigns from Pep Boys aft...
# 8
# 9  Papatzul, Mexican restaurant in SoHo, offers h...
#
#                                       lead_paragraph print_section print_page  \
# 0  The ethnic patterns, colors and embellishment ...             9          4
# 1  IT seems as if Madison Avenue is on some kind ...             C          4
# 2  Five years since starting its green marketing ...           NaN        NaN
# 3  Private schools in India are often attractive ...           NaN        NaN
# 4  MORE than 60 years later, John T. Steck still ...            CN         14
# 5  There is a certain type of New Yorker who live...            MB          8
# 6  "Pay me or trade me. Click." That, more or les...             8          8
# 7  Just a few months ago, Lawrence N. Stevenson, ...             3          2
# 8  IF YOU WANT TO GET with it in terms of nomencl...             6         24
# 9  LET'S not play around. I know what you'll be d...             9          7
#
#                source                                         multimedia  \
# 0  The New York Times                                                 []
# 1  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2  The New York Times                                                 []
# 3  The New York Times                                                 []
# 4  The New York Times                                                 []
# 5  The New York Times  [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# 6  The New York Times                                                 []
# 7  The New York Times                                                 []
# 8  The New York Times                                                 []
# 9  The New York Times                                                 []
#
#                                             keywords  \
# 0                                                 []
# 1  [{'name': 'subject', 'value': 'Trademarks and ...
# 2                                                 []
# 3  [{'name': 'subject', 'value': 'Private and Sec...
# 4  [{'name': 'organizations', 'value': 'Dodd, Tho...
# 5  [{'name': 'subject', 'value': 'Photography', '...
# 6  [{'name': 'organizations', 'value': 'Green Bay...
# 7  [{'name': 'organizations', 'value': 'Pep Boys'...
# 8  [{'name': 'glocations', 'value': 'Europe', 'ra...
# 9  [{'name': 'glocations', 'value': 'New York Cit...
#
#                    pub_date document_type                          news_desk  \
# 0  2005-05-29T05:00:00+0000       article                         Style Desk
# 1  2007-05-24T04:00:00+0000       article                           Business
# 2  2010-09-20T20:20:40+0000       article
# 3  2012-01-03T07:39:03+0000       article
# 4  1998-11-15T05:00:00+0000       article            Connecticut Weekly Desk
# 5  2014-02-08T00:03:56+0000       article                              Metro
# 6  1992-08-16T05:00:00+0000       article                        Sports Desk
# 7  2006-07-23T05:00:00+0000       article  Money and Business/Financial Desk
# 8  1995-03-12T05:00:00+0000       article                      Magazine Desk
# 9  2006-12-31T05:00:00+0000       article                         Style Desk
#
#    section_name type_of_material  \
# 0         Style             News
# 1  Business Day             News
# 2  Business Day              NaN
# 3         World             News
# 4      New York             News
# 5      New York             News
# 6        Sports             News
# 7  Business Day             News
# 8      Magazine             News
# 9         Style             News
#
#                                                  _id  word_count  \
# 0  nyt://article/44f3904d-fa10-5de7-a543-65966baa...         137
# 1  nyt://article/c4ffce82-817d-5fd6-8870-8cd1cf5e...         888
# 2  nyt://article/2d903714-4ecc-505f-843f-56dd162e...         334
# 3  nyt://article/5ef38367-95f6-5566-8073-ebe5199c...          59
# 4  nyt://article/e8bdfaf4-a096-5e13-bfc2-016e5914...        1537
# 5  nyt://article/9e709149-dec2-548b-85c1-ceba1e38...         240
# 6  nyt://article/2f07faeb-9369-5a24-b6e1-71f6cab1...         188
# 7  nyt://article/dca25f65-4853-58ea-a282-1654a1bd...         110
# 8  nyt://article/801bbb54-e581-5570-907f-aaf6a84b...        1077
# 9  nyt://article/a46cd116-6394-5f8e-a351-2d266fa2...         485
#
#                                                  uri  \
# 0  nyt://article/44f3904d-fa10-5de7-a543-65966baa...
# 1  nyt://article/c4ffce82-817d-5fd6-8870-8cd1cf5e...
# 2  nyt://article/2d903714-4ecc-505f-843f-56dd162e...
# 3  nyt://article/5ef38367-95f6-5566-8073-ebe5199c...
# 4  nyt://article/e8bdfaf4-a096-5e13-bfc2-016e5914...
# 5  nyt://article/9e709149-dec2-548b-85c1-ceba1e38...
# 6  nyt://article/2f07faeb-9369-5a24-b6e1-71f6cab1...
# 7  nyt://article/dca25f65-4853-58ea-a282-1654a1bd...
# 8  nyt://article/801bbb54-e581-5570-907f-aaf6a84b...
# 9  nyt://article/a46cd116-6394-5f8e-a351-2d266fa2...
#
#                                     headline.main          headline.kicker  \
# 0                                     Hello Again            ON THE STREET
# 1     Madison Avenue Says Hello to ‘Hello,’ Again              Advertising
# 2            G.E. Says, ‘Eco! Eco! Hello! Hello!’            Media Decoder
# 3         Hello, How Are You? Hello, How Are You?                India Ink
# 4  From 'Hello, Central' to 'Hello, Conglomerate'                     None
# 5                  Hello, Non-Manhattan Neighbors                    Album
# 6                   Hello? Hello? Deal Is Hung Up  SPORTS PEOPLE: FOOTBALL
# 7                               HELLO AND GOODBYE           OPENERS: SUITS
# 8                                  Hello, Central              ON LANGUAGE
# 9                                 Hello, Tomorrow       SHAKEN AND STIRRED
#
#   headline.content_kicker                            headline.print_headline  \
# 0                    None                         ON THE STREET; Hello Again
# 1                    None        Madison Avenue Says Hello to ‘Hello,’ Again
# 2                    None                                               None
# 3                    None                                               None
# 4                    None     From 'Hello, Central' to 'Hello, Conglomerate'
# 5                    None                                  Hello, Neighbors!
# 6                    None  SPORTS PEOPLE: FOOTBALL; Hello? Hello? Deal Is...
# 7                    None                  OPENERS: SUITS; HELLO AND GOODBYE
# 8                    None                        ON LANGUAGE; Hello, Central
# 9                    None                SHAKEN AND STIRRED; Hello, Tomorrow
#
#   headline.name headline.seo headline.sub      byline.original  \
# 0          None         None         None   By Bill Cunningham
# 1          None         None         None    By Stuart Elliott
# 2          None         None         None    By Stuart Elliott
# 3          None         None         None  By Sruthi Gottipati
# 4          None         None         None       By Bill Slocum
# 5          None         None         None        By Alan Feuer
# 6          None         None         None                 None
# 7          None         None         None  By Jeremy W. Peters
# 8          None         None         None    By William Safire
# 9          None         None         None    By Jonathan Miles
#
#                                        byline.person byline.organization  \
# 0  [{'firstname': 'Bill', 'middlename': None, 'la...                None
# 1  [{'firstname': 'Stuart', 'middlename': None, '...                None
# 2  [{'firstname': 'Stuart', 'middlename': None, '...                None
# 3  [{'firstname': 'Sruthi', 'middlename': None, '...                None
# 4  [{'firstname': 'Bill', 'middlename': None, 'la...                None
# 5  [{'firstname': 'Alan', 'middlename': None, 'la...                None
# 6                                                 []                None
# 7  [{'firstname': 'Jeremy', 'middlename': 'W.', '...                None
# 8  [{'firstname': 'William', 'middlename': None, ...                None
# 9  [{'firstname': 'Jonathan', 'middlename': None,...                None
#
#   subsection_name
# 0             NaN
# 1           Media
# 2           Media
# 3    Asia Pacific
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
